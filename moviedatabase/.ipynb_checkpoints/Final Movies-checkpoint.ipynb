# %%
import pandas as pd

# %%
from collections import Counter

# %%
movies_metadata_df = pd.read_csv("data/movies_metadata.csv")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movies_metadata_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
keywords_df = pd.read_csv("data/keywords.csv")

# %%
keywords_df.head(15)
# Out:
#        id                                           keywords
# 0     862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1    8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2   15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3   31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4   11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 5     949  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 6   11860  [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# 7   45325                                                 []
# 8    9091  [{'id': 949, 'name': 'terrorist'}, {'id': 1562...
# 9     710  [{'id': 701, 'name': 'cuba'}, {'id': 769, 'nam...
# 10   9087  [{'id': 833, 'name': 'white house'}, {'id': 84...
# 11  12110  [{'id': 3633, 'name': 'dracula'}, {'id': 11931...
# 12  21032  [{'id': 1994, 'name': 'wolf'}, {'id': 6411, 'n...
# 13  10858  [{'id': 840, 'name': 'usa president'}, {'id': ...
# ...

# %%
id_toystory = movies_metadata_df [movies_metadata_df.original_title == "Toy Story"].id

# %%
type(id_toystory)
# Out:
# pandas.core.series.Series

# %%
keywords_toy = keywords_df [keywords_df.id == int(id_toystory)].keywords

# %%
keywords_toy
# Out:
# 0    [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# Name: keywords, dtype: object

# %%
import json

# %%
for name in keywords_toy[0]:
    #keywords_dictionary = json.loads(name)
    print(name)
# Out:
# [
# {
# '
# i
# d
# '
# :
#
# 9
# 3
# 1
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# j
# e
# a
# l
# o
# u
# s
# y
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 4
# 2
# 9
# 0
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# t
# o
# y
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 5
# 2
# 0
# 2
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# b
# o
# y
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 6
# 0
# 5
# 4
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# f
# r
# i
# e
# n
# d
# s
# h
# i
# p
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 9
# 7
# 1
# 3
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# f
# r
# i
# e
# n
# d
# s
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 9
# 8
# 2
# 3
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# r
# i
# v
# a
# l
# r
# y
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 1
# 6
# 5
# 5
# 0
# 3
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# b
# o
# y
#
# n
# e
# x
# t
#
# d
# o
# o
# r
# '
# }
# ,
#
# {
# '
# i
# d
# '
# :
#
# 1
# 7
# 0
# 7
# 2
# 2
# ,
#
# '
# n
# a
# m
# e
# '
# :
#
# '
# n
# e
# w
#
# t
# o
# y
# '
# ...

# %%
print(keywords_toy[0].replace("[","").replace("]","").replace("{"," ").replace("}"," ").replace("'id':"," "))
# Out:
#    931, 'name': 'jealousy' ,    4290, 'name': 'toy' ,    5202, 'name': 'boy' ,    6054, 'name': 'friendship' ,    9713, 'name': 'friends' ,    9823, 'name': 'rivalry' ,    165503, 'name': 'boy next door' ,    170722, 'name': 'new toy' ,    187065, 'name': 'toy comes to life'

# %%
keywords_toy_SRT = keywords_toy[0].replace("[","").replace("]","")

# %%
from collections import Counter

# %%
recuento_de_adultos = Counter(movies_metadata_df.adult)

# %%
recuento_de_adultos
# Out:
# Counter({'False': 45454,
#          'True': 9,
#          ' - Written by Ørnås': 1,
#          ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.': 1,
#          ' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.': 1})

# %%
pelis_adultos = movies_metadata_df.sort_values( by = "adult", ascending = True)

# %%
pelis_adultos
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 35587   Avalanche Sharks tells the story of a bikini ...
# 29503   Rune Balot goes to a casino connected to the ...
# 0                                                  False
# 30300                                              False
# 30301                                              False
# 30302                                              False
# 30303                                              False
# 30304                                              False
# 30305                                              False
# 30306                                              False
# 30307                                              False
# 30309                                              False
# 30310                                              False
# 30311                                              False
# ...

# %%
recuento_genero = Counter(movies_metadata_df.genres)

# %%
recuento_genero
# Out:
# Counter({"[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]": 72,
#          "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]": 16,
#          "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]": 213,
#          "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]": 593,
#          "[{'id': 35, 'name': 'Comedy'}]": 3621,
#          "[{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]": 97,
#          "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]": 930,
#          "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]": 22,
#          "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 53, 'name': 'Thriller'}]": 59,
# ...

# %% [markdown]
# Desde aquí, decidí cambiar de base de datos a la de IMBD, pues, los datos de la otra estaban mal organizados e incompletos. Estas son las fuentes de las bases de datos nuevas: https://datasets.imdbws.com/ https://www.imdb.com/interfaces/

# %%
imdb_metadata_df = pd.read_csv("data/imdb_title_basics.csv")

# %%
imdb_metadata_df.shape
# Out:
# (65499, 9)

# %%
imdb_metadata_df.head(5)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult  startYear endYear runtimeMinutes                    genres
# 0        0       1894      \N              1         Documentary,Short
# 1        0       1892      \N              5           Animation,Short
# 2        0       1892      \N              4  Animation,Comedy,Romance
# 3        0       1892      \N             \N           Animation,Short
# 4        0       1893      \N              1              Comedy,Short

# %%
recuento_de_adultos_imdb = Counter(imdb_metadata_df.isAdult)

# %%
recuento_de_adultos_imdb
# Out:
# Counter({0: 65477, 1: 22})

# %%
recuento_de_adultos_print = imdb_metadata_df.sort_values( by = "isAdult", ascending = False)

# %%
recuento_de_adultos_print
# Out:
#           tconst titleType                                       primaryTitle  \
# 61905  tt0063118     movie                                        I Want You!
# 63927  tt0065197     movie                                     We All Go Down
# 64167  tt0065442     movie                                         Bacchanale
# 61168  tt0062361     movie                                          Thigh Spy
# 64766  tt0066055     movie  Man & Wife: An Educational Film for Married Ad...
# 61962  tt0063176     movie                                              Karla
# 64395  tt0065676     movie                                       Dirty Lovers
# 65058  tt0066357     movie                    Les cauchemars naissent la nuit
# 64803  tt0066092     movie                             Mona: The Virgin Nymph
# 65151  tt0066453     movie                                The Three Sexateers
# 64123  tt0065397     movie                         The Adult Workshop of Love
# ...

# %%
recuento_genero_imdb = Counter(imdb_metadata_df.genres)

# %%
recuento_genero_imdb
# Out:
# Counter({'Documentary,Short': 1129,
#          'Animation,Short': 662,
#          'Animation,Comedy,Romance': 8,
#          'Comedy,Short': 3026,
#          'Short': 1264,
#          'Short,Sport': 16,
#          'Romance': 254,
#          'Action,Documentary,Short': 1,
#          'Documentary,Short,Sport': 27,
#          'News,Short': 12,
#          'News,Short,Sport': 3,
#          'Comedy,Documentary,Short': 6,
#          'Drama,Short': 1565,
#          'Action,Comedy,Documentary': 1,
#          'Fantasy,Short': 33,
#          'Horror,Short': 28,
#          'Comedy,Horror,Short': 9,
#          'Biography,Short': 13,
#          'Music,Short': 57,
#          'Documentary,News,Sport': 1,
#          'Fantasy,Horror,Short': 7,
#          'Short,War': 30,
#          'Crime,Short': 23,
#          'Short,Western': 532,
#          'Comedy,Short,Sport': 18,
#          'Comedy,Fantasy,Horror': 17,
#          'Biography,Drama,Short': 7,
#          'Romance,Short': 69,
# ...

# %%
type(imdb_metadata_df.genres)
# Out:
# pandas.core.series.Series

# %%
genero_split = imdb_metadata_df.genres.str.split(",")

# %%
type(genero_split)
# Out:
# pandas.core.series.Series

# %%
generos_comunes = recuento_genero_imdb.most_common()

# %%
generos_comunes
# Out:
# [('Drama', 10488),
#  ('Comedy', 5952),
#  ('\\N', 5229),
#  ('Comedy,Short', 3026),
#  ('Western', 2396),
#  ('Animation,Comedy,Family', 2030),
#  ('Drama,Romance', 1798),
#  ('Drama,Short', 1565),
#  ('Crime,Drama', 1436),
#  ('Short', 1264),
#  ('Comedy,Drama', 1242),
#  ('Comedy,Romance', 1136),
#  ('Documentary,Short', 1129),
#  ('Documentary', 917),
#  ('Animation,Comedy,Short', 848),
#  ('Drama,War', 824),
#  ('Comedy,Musical', 677),
#  ('Animation,Short', 662),
#  ('Adventure', 634),
#  ('Short,Western', 532),
#  ('Crime,Drama,Film-Noir', 512),
#  ('Action,Adventure,Drama', 496),
#  ('Comedy,Drama,Romance', 471),
#  ('Comedy,Musical,Romance', 413),
#  ('Mystery', 363),
#  ('Musical', 362),
#  ('Crime,Drama,Mystery', 323),
#  ('Crime', 322),
#  ('Action,Crime,Drama', 303),
#  ('Comedy,Music', 276),
#  ('Crime,Drama,Romance', 267),
#  ('Adventure,Drama', 266),
#  ('Action,Adventure,Crime', 264),
#  ('Romance', 254),
#  ('Drama,History', 250),
#  ('Comedy,Crime', 244),
# ...

# %%
# Numpy
import numpy as np
import matplotlib.pyplot as plt

# %%
recuento_ano_imdb = Counter(imdb_metadata_df.startYear)

# %%
movies_metadata_df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#      ...     release_date      revenue runtime  \
# 0    ...       1995-10-30  373554033.0    81.0
# 1    ...       1995-12-15  262797249.0   104.0
#
# ...

# %%
ratings_chidos = movies_metadata_df.sort_values( by = "vote_average", ascending = False)

# %%
ratings_chidos
# Out:
#                                                    adult  \
# 21642                                              False
# 15710                                              False
# 22396                                              False
# 22395                                              False
# 35343                                              False
# 186                                                False
# 45047                                              False
# 22377                                              False
# 22346                                              False
# 1634                                               False
# 35461                                              False
# 22255                                              False
# 45005                                              False
# 41879                                              False
# 41845                                              False
# ...

# %%
recuento_genero_ratings = Counter(ratings_chidos.genres)

# %%
recuento_genero_ratings_ordenados = recuento_genero_ratings.most_common()
recuento_genero_ratings_ordenados
# Out:
# [("[{'id': 18, 'name': 'Drama'}]", 5000),
#  ("[{'id': 35, 'name': 'Comedy'}]", 3621),
#  ("[{'id': 99, 'name': 'Documentary'}]", 2723),
#  ('[]', 2442),
#  ("[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]", 1301),
#  ("[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]", 1135),
#  ("[{'id': 27, 'name': 'Horror'}]", 974),
#  ("[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]", 930),
#  ("[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#   593),
#  ("[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]", 532),
#  ("[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]", 528),
#  ("[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]", 497),
#  ("[{'id': 53, 'name': 'Thriller'}]", 465),
#  ("[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]", 430),
#  ("[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}]", 343),
# ...

# %%
ratings_chidos = ratings_chidos[ratings_chidos.vote_count > 100]

# %%
budgets_ratings_altos = ratings_chidos.sort_values(by=["vote_average", "budget"], ascending= [False,True])

# %%
budgets_ratings_altos.head(10)
# Out:
#        adult belongs_to_collection    budget  \
# 43320  False                   NaN         0
# 43523  False                   NaN         0
# 10309  False                   NaN  13200000
# 42491  False                   NaN         0
# 39085  False                   NaN         0
# 6747   False                   NaN         0
# 7643   False                   NaN         0
# 2743   False                   NaN   1200000
# 29183  False                   NaN         0
# 33420  False                   NaN  13000000
#
#                                                   genres  \
# 43320                [{'id': 99, 'name': 'Documentary'}]
# 43523                                                 []
# 10309  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 42491                   [{'id': 10402, 'name': 'Music'}]
# 39085                [{'id': 99, 'name': 'Documentary'}]
# 6747                 [{'id': 99, 'name': 'Documentary'}]
# 7643                       [{'id': 18, 'name': 'Drama'}]
# ...

# %%
budgets_ratings_mas_altos = budgets_ratings_altos.head(300)

# %%
mega_budgets = budgets_ratings_altos.budget

# %%
movies_metadata_df.shape
# Out:
# (45466, 24)

# %%
m_ratings_altos = ratings_chidos.sort_values(by=["vote_average"], ascending= [False])

# %%
m_ratings_altos
# Out:
#        adult                              belongs_to_collection     budget  \
# 10309  False                                                NaN   13200000
# 39085  False                                                NaN          0
# 314    False                                                NaN   25000000
# 834    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 40251  False                                                NaN          0
# 13252  False                                                NaN          0
# 2211   False                                                NaN   20000000
# 5481   False                                                NaN   15000000
# 44677  False                                                NaN          0
# 292    False                                                NaN    8000000
# 45437  False                                                NaN          0
# ...
